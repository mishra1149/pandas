# %%
import numpy as np
import pandas as pd

# %% [markdown]
# CREATE DATAFRAME

# %%
data ={
    'name':['shivam','mishra','pathak','golu'],
    'AGE':[12,24,45,21],
    'CITY':['delhi','osai','palla','xyz'],
    'SALARY':[25555,34343,343432,54545]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#      name  AGE   CITY  SALARY
# 0  shivam   12  delhi   25555
# 1  mishra   24   osai   34343
# 2  pathak   45  palla  343432
# 3    golu   21    xyz   54545

# %%
data_list =[
    ['joy',27,'paris',636363],
    ['luis',32,'usa',5656],
    ['fio',31,'america',8888],
    ['jio',76,'polo',41414]
]
df2 =pd.DataFrame(data_list)
# columns=['name','age','city','salary']
# df2=pd.DataFrame(data_list,columns=columns) #is wale me index nhai ha to index ke liye hamne column ka kaam kiya ha 
df2
# Out:
#       0   1        2       3
# 0   joy  27    paris  636363
# 1  luis  32      usa    5656
# 2   fio  31  america    8888
# 3   jio  76     polo   41414

# %%
columns=['name','age','city','salary']
df2=pd.DataFrame(data_list,columns=columns)
df2
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %%
df
# Out:
#      name  AGE   CITY  SALARY
# 0  shivam   12  delhi   25555
# 1  mishra   24   osai   34343
# 2  pathak   45  palla  343432
# 3    golu   21    xyz   54545

# %%
df2
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %% [markdown]
# SELECTION AND INDEXING OF COLUMN

# %%
df2
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %%
df2['name']
# Out:
# 0     joy
# 1    luis
# 2     fio
# 3     jio
# Name: name, dtype: str

# %%
df2['city']
# Out:
# 0      paris
# 1        usa
# 2    america
# 3       polo
# Name: city, dtype: str

# %% [markdown]
# CREATING A COLUMN

# %%
df2['designation']=['doctor','engi','doctor','engineer']
df2
# Out:
#    name  age     city  salary designation
# 0   joy   27    paris  636363      doctor
# 1  luis   32      usa    5656        engi
# 2   fio   31  america    8888      doctor
# 3   jio   76     polo   41414    engineer

# %% [markdown]
# TEMPORARY DLT COLUMN

# %%
df2.drop('designation',axis=1)  #yaha par designation remove ho gaya but actual database me avu v ha it is only snapshot
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %%
df2 # here if we get the data of d2 yaha exist kr raha ha
# Out:
#    name  age     city  salary designation
# 0   joy   27    paris  636363      doctor
# 1  luis   32      usa    5656        engi
# 2   fio   31  america    8888      doctor
# 3   jio   76     polo   41414    engineer

# %% [markdown]
# PERMANENTLY DLT COLUMN

# %%
df2
# Out:
#    name  age     city  salary designation
# 0   joy   27    paris  636363      doctor
# 1  luis   32      usa    5656        engi
# 2   fio   31  america    8888      doctor
# 3   jio   76     polo   41414    engineer

# %%
df2.drop('designation',axis=1,inplace=True)

# %%
df2
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %% [markdown]
# delete multiple column

# %%
df2.drop(['city','salary'],axis=1) #temp hua h
# Out:
#    name  age
# 0   joy   27
# 1  luis   32
# 2   fio   31
# 3   jio   76

# %%
df2
# Out:
#    name  age     city  salary
# 0   joy   27    paris  636363
# 1  luis   32      usa    5656
# 2   fio   31  america    8888
# 3   jio   76     polo   41414

# %% [markdown]
# making a colmun

# %%
df2['designation']=['dr','eng','pilot','ai eng']

# %%
df2
# Out:
#    name  age     city  salary designation
# 0   joy   27    paris  636363          dr
# 1  luis   32      usa    5656         eng
# 2   fio   31  america    8888       pilot
# 3   jio   76     polo   41414      ai eng

# %% [markdown]
# making a multiple colmun

# %%
df2[['gender','experience']]=[['m',12],['m',3],['m',6],['m',7]]

# %%
df2
# Out:
#    name  age     city  salary designation gender experience
# 0   joy   27    paris  636363          dr      m         12
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %% [markdown]
# delete a row

# %%
df2.drop(0,axis=0) #ye temp hua ha
# Out:
#    name  age     city  salary designation gender experience
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %%
df2
# Out:
#    name  age     city  salary designation gender experience
# 0   joy   27    paris  636363          dr      m         12
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %%
df2.drop([0,1]) # we can provide axis 0 or not cozz in pandas default it set to the zero multiple row delete
# Out:
#   name  age     city  salary designation gender experience
# 2  fio   31  america    8888       pilot      m          6
# 3  jio   76     polo   41414      ai eng      m          7

# %%
df2
# Out:
#    name  age     city  salary designation gender experience
# 0   joy   27    paris  636363          dr      m         12
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %% [markdown]
# selecting a row

# %%
df2.loc[0] #loc means location
# Out:
# name              joy
# age                27
# city            paris
# salary         636363
# designation        dr
# gender              m
# experience         12
# Name: 0, dtype: object

# %%
df2.loc[[0,1]] #multiple select a row
# Out:
#    name  age   city  salary designation gender experience
# 0   joy   27  paris  636363          dr      m         12
# 1  luis   32    usa    5656         eng      m          3

# %%
df2.iloc[0] #iloc means index location
# Out:
# name              joy
# age                27
# city            paris
# salary         636363
# designation        dr
# gender              m
# experience         12
# Name: 0, dtype: object

# %% [markdown]
# SELECTIng suset of rows and columns

# %%
df2
# Out:
#    name  age     city  salary designation gender experience
# 0   joy   27    paris  636363          dr      m         12
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %%
df2.loc[[0,1]] [['city','salary']] #here i need only the city and salary
# Out:
#     city  salary
# 0  paris  636363
# 1    usa    5656

# %%
df2.loc[[2,3]] [['name','age']]
# Out:
#   name  age
# 2  fio   31
# 3  jio   76

# %% [markdown]
# conditional statements

# %%
df2
# Out:
#    name  age     city  salary designation gender experience
# 0   joy   27    paris  636363          dr      m         12
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %%
#whise age above 30

# %%
df2[df2['age']>30]
# Out:
#    name  age     city  salary designation gender experience
# 1  luis   32      usa    5656         eng      m          3
# 2   fio   31  america    8888       pilot      m          6
# 3   jio   76     polo   41414      ai eng      m          7

# %%
#whise age above 30 and from usa

# %%
df2[(df2['age']>30) & (df2['city']=='usa')]
# Out:
#    name  age city  salary designation gender experience
# 1  luis   32  usa    5656         eng      m          3

# %%
#whose salary 60k greater or age 20 city paris

# %%
df2[(df2['age']>20) & (df2['salary']>60000) &(df2['city']=='paris')]
# Out:
#   name  age   city  salary designation gender experience
# 0  joy   27  paris  636363          dr      m         12

# %%
df2[(df2['age']>30) & (df2['city']=='america') & (df2['designation']=='pilot') & (df2['salary']>100)]
# Out:
#   name  age     city  salary designation gender experience
# 2  fio   31  america    8888       pilot      m          6
